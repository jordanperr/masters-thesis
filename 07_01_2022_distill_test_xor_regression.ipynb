# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

# %% [markdown]
# # First Example: XOR Network Distillation and Verification
#
# In this notebook, we demonstrate network distillation and verification in a loop. First, we train an overparametrized network on the xor problem, graphing the decision boundary. Next we distill this network using Hinton distillation. Finally, we verify both networks using nnenum to check that the decision is stable within a certain region.

# %% [markdown]
# ## The XOR dataset
# Here is the dataset we will train with. It includes 1000 uniformly distributed samples of the xor function within the region (-1,1) of the $\mathbb{R}^2$ plane.

# %%
def dataset_xor_uniform(n=1000):
    i1 = np.random.random(n)*2-1
    i2 = np.random.random(n)*2-1
    target = np.logical_xor(i1>0, i2>0).astype(int)
    return np.array([i1, i2]), np.array([target])

inputs, outputs = dataset_xor_uniform()

# %%
plt.scatter(inputs[0], inputs[1], c=outputs)
plt.title("Uniform XOR Dataset (n=1000)")
plt.xlabel("Input 0")
plt.ylabel("Input 1")
plt.show()

# %% [markdown]
# ## Train teacher network
#
# Now, train a fully connected neural network on this dataset with ~5,000 free parameters for 100 epochs.

# %%
num_observations = inputs.shape[1]
num_inputs = inputs.shape[0]
num_outputs = outputs.shape[0]

hidden_layer_width=50
num_hidden_layers=3

## Input Layer
layers = [
    tf.keras.layers.Dense(
        hidden_layer_width,
        activation=tf.nn.relu,
        input_shape=(num_inputs,),
        kernel_initializer=tf.keras.initializers.GlorotUniform(),
        bias_initializer=tf.keras.initializers.GlorotUniform()
    )
]

## Hidden Layers
for i in range(num_hidden_layers-1):
    layers.append(
        tf.keras.layers.Dense(hidden_layer_width,
            activation=tf.nn.relu,
            kernel_initializer=tf.keras.initializers.GlorotUniform(),
            bias_initializer=tf.keras.initializers.GlorotUniform())
    )

## Output Layer
layers.append(tf.keras.layers.Dense(num_outputs, activation=tf.nn.relu))

model = tf.keras.Sequential(layers)

model.compile(
# loss=tf.keras.losses.BinaryCrossentropy(), # binary classification
# loss='categorical_crossentropy', # categorical classification (one hot)
loss='mean_squared_error',  # regression
optimizer=tf.keras.optimizers.Adam(0.001),
# optimizer='rmsprop',
metrics=['mean_squared_error'],
)

model.fit(
    x=inputs.T,
    y=outputs.T,
    shuffle=True,
    validation_split=.2,
    epochs=100,
    batch_size=128,
    )

model.summary()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4435 - mean_squared_error: 0.4435 - val_loss: 0.3453 - val_mean_squared_error: 0.3453
# Epoch 2/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3040 - mean_squared_error: 0.3040 - val_loss: 0.2311 - val_mean_squared_error: 0.2311
# Epoch 3/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2170 - mean_squared_error: 0.2170 - val_loss: 0.1965 - val_mean_squared_error: 0.1965
# Epoch 4/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1890 - mean_squared_error: 0.1890 - val_loss: 0.1666 - val_mean_squared_error: 0.1666
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1550 - mean_squared_error: 0.1550 - val_loss: 0.1330 - val_mean_squared_error: 0.1330
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1233 - mean_squared_error: 0.1233 - val_loss: 0.1087 - val_mean_squared_error: 0.1087
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1000 - mean_squared_error: 0.1000 - val_loss: 0.0910 - val_mean_squared_error: 0.0910
# Epoch 8/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0860 - mean_squared_error: 0.0860 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Epoch 9/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0771 - mean_squared_error: 0.0771 - val_loss: 0.0796 - val_mean_squared_error: 0.0796
# Epoch 10/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0711 - mean_squared_error: 0.0711 - val_loss: 0.0722 - val_mean_squared_error: 0.0722
# Epoch 11/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0668 - mean_squared_error: 0.0668 - val_loss: 0.0686 - val_mean_squared_error: 0.0686
# Epoch 12/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0625 - mean_squared_error: 0.0625 - val_loss: 0.0656 - val_mean_squared_error: 0.0656
# Epoch 13/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0588 - mean_squared_error: 0.0588 - val_loss: 0.0610 - val_mean_squared_error: 0.0610
# Epoch 14/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0560 - mean_squared_error: 0.0560 - val_loss: 0.0582 - val_mean_squared_error: 0.0582
# Epoch 15/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0542 - mean_squared_error: 0.0542 - val_loss: 0.0558 - val_mean_squared_error: 0.0558
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0522 - mean_squared_error: 0.0522 - val_loss: 0.0549 - val_mean_squared_error: 0.0549
# Epoch 17/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0493 - mean_squared_error: 0.0493 - val_loss: 0.0518 - val_mean_squared_error: 0.0518
# Epoch 18/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 0.0505 - val_mean_squared_error: 0.0505
# Epoch 19/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0458 - mean_squared_error: 0.0458 - val_loss: 0.0485 - val_mean_squared_error: 0.0485
# Epoch 20/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0437 - mean_squared_error: 0.0437 - val_loss: 0.0462 - val_mean_squared_error: 0.0462
# Epoch 21/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0421 - mean_squared_error: 0.0421 - val_loss: 0.0452 - val_mean_squared_error: 0.0452
# Epoch 22/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.0435 - val_mean_squared_error: 0.0435
# Epoch 23/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0423 - val_mean_squared_error: 0.0423
# Epoch 24/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
# Epoch 25/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
# Epoch 26/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0389 - val_mean_squared_error: 0.0389
# Epoch 27/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 28/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0323 - mean_squared_error: 0.0323 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 29/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 30/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0367 - val_mean_squared_error: 0.0367
# Epoch 31/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0296 - mean_squared_error: 0.0296 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 32/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0361 - val_mean_squared_error: 0.0361
# Epoch 33/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 34/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 36/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 37/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 38/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
# Epoch 39/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0301 - val_mean_squared_error: 0.0301
# Epoch 40/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
# Epoch 41/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0310 - val_mean_squared_error: 0.0310
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.0300 - val_mean_squared_error: 0.0300
# Epoch 43/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 44/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 45/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 46/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 47/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 48/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0281 - val_mean_squared_error: 0.0281
# Epoch 49/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 50/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 51/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 52/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 53/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 54/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 55/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 56/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 57/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 58/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 59/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 60/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 61/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 62/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 63/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 64/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 65/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 66/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 67/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 68/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 69/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 70/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 71/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 72/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 73/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 74/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 75/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 76/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 77/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 78/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 79/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 80/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 81/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 82/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 83/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 85/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 86/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 87/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 88/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 89/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 90/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 91/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 92/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 93/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 94/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 95/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 96/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 97/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 98/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 99/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 100/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 50)                150
#
#  dense_9 (Dense)             (None, 50)                2550
#
#  dense_10 (Dense)            (None, 50)                2550
#
#  dense_11 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 5,301
# Trainable params: 5,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = model.predict(inputs.T)

X = np.linspace(-2,2,100)
Y = X.copy()
xx,yy = np.meshgrid(X,Y)
labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
z = labels.reshape(xx.shape)
 
plt.contour(xx,yy,z, label="Prediction (large)")
plt.scatter(inputs[0], inputs[1], c=outputs[0], marker=".", label="original data")
plt.legend()
plt.title("Prediction of large network over original data")
plt.xlabel("Input 0")
plt.ylabel("Input 1")
plt.show()
# Out:
# 32/32 [==============================] - 0s 897us/step
# 313/313 [==============================] - 0s 1ms/step
# /var/folders/3g/8436y4yj1r9367dvt15y6jqcdx0hcv/T/ipykernel_61116/2471555115.py:9: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xx,yy,z, label="Prediction (large)")

# %% [markdown]
# With 20,601 trainable parameters, we are able to get a pretty good decision boundary at least for the in-sample region (-1,1). However, we can see that the network has not learned the exact XOR rule, as evidenced by some unnecessary level curves at the edges of the decision boundary. One may ask the question, does this network faithfully compute XOR throughout the entire $\mathbb{R}^2$ plane?

# %% [markdown]
# ## Train student network using Hinton Distillation

# %%
## Import distiller class from example in Tensorflow documentation
from lib.knowledge_distillation import Distiller

# %%
num_observations = inputs.shape[1]
num_inputs = inputs.shape[0]
num_outputs = outputs.shape[0]

hidden_layer_width=10
num_hidden_layers=3

## Input Layer
layers = [
    tf.keras.layers.Dense(
        hidden_layer_width,
        activation=tf.nn.relu,
        input_shape=(num_inputs,),
        kernel_initializer=tf.keras.initializers.GlorotUniform(),
        bias_initializer=tf.keras.initializers.GlorotUniform()
    )
]

## Hidden Layers
for i in range(num_hidden_layers-1):
    layers.append(
        tf.keras.layers.Dense(hidden_layer_width,
            activation=tf.nn.relu,
            kernel_initializer=tf.keras.initializers.GlorotUniform(),
            bias_initializer=tf.keras.initializers.GlorotUniform())
    )

## Output Layer
layers.append(tf.keras.layers.Dense(num_outputs, activation=tf.nn.relu))

student_model = tf.keras.Sequential(layers)

distiller = Distiller(student=student_model, teacher=model)

distiller.compile(
    student_loss_fn=tf.keras.losses.MeanSquaredError(),  # regression
    distillation_loss_fn=tf.keras.losses.KLDivergence(),  # regression
    optimizer=tf.keras.optimizers.Adam(0.001),
    metrics=[tf.keras.metrics.MeanSquaredError()],
    alpha=0.1,
    temperature=10.0
)

distiller.fit(
    x=inputs.T,
    y=outputs.T,
    # shuffle=True,
    # validation_split=.2,
    epochs=100,
    # batch_size=128,
    )
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 1ms/step - mean_squared_error: 0.2847 - student_loss: 0.2833 - distillation_loss: 0.0000e+00
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.2140 - student_loss: 0.2126 - distillation_loss: 0.0000e+00
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.1705 - student_loss: 0.1712 - distillation_loss: 0.0000e+00
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.1326 - student_loss: 0.1289 - distillation_loss: 0.0000e+00
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.1026 - student_loss: 0.1001 - distillation_loss: 0.0000e+00
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0850 - student_loss: 0.0864 - distillation_loss: 0.0000e+00
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0747 - student_loss: 0.0741 - distillation_loss: 0.0000e+00
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0684 - student_loss: 0.0677 - distillation_loss: 0.0000e+00
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0648 - student_loss: 0.0624 - distillation_loss: 0.0000e+00
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0620 - student_loss: 0.0618 - distillation_loss: 0.0000e+00
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0593 - student_loss: 0.0585 - distillation_loss: 0.0000e+00
# Epoch 12/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0570 - student_loss: 0.0593 - distillation_loss: 0.0000e+00
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0563 - student_loss: 0.0558 - distillation_loss: 0.0000e+00
# Epoch 14/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0540 - student_loss: 0.0547 - distillation_loss: 0.0000e+00
# Epoch 15/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0529 - student_loss: 0.0524 - distillation_loss: 0.0000e+00
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0512 - student_loss: 0.0515 - distillation_loss: 0.0000e+00
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0500 - student_loss: 0.0513 - distillation_loss: 0.0000e+00
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0488 - student_loss: 0.0515 - distillation_loss: 0.0000e+00
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0476 - student_loss: 0.0489 - distillation_loss: 0.0000e+00
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0462 - student_loss: 0.0444 - distillation_loss: 0.0000e+00
# Epoch 21/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0455 - student_loss: 0.0460 - distillation_loss: 0.0000e+00
# Epoch 22/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0441 - student_loss: 0.0443 - distillation_loss: 0.0000e+00
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0441 - student_loss: 0.0449 - distillation_loss: 0.0000e+00
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0414 - student_loss: 0.0397 - distillation_loss: 0.0000e+00
# Epoch 25/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0406 - student_loss: 0.0416 - distillation_loss: 0.0000e+00
# Epoch 26/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0398 - student_loss: 0.0394 - distillation_loss: 0.0000e+00
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0388 - student_loss: 0.0370 - distillation_loss: 0.0000e+00
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0374 - student_loss: 0.0365 - distillation_loss: 0.0000e+00
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0370 - student_loss: 0.0355 - distillation_loss: 0.0000e+00
# Epoch 30/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0352 - student_loss: 0.0345 - distillation_loss: 0.0000e+00
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0345 - student_loss: 0.0358 - distillation_loss: 0.0000e+00
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0339 - student_loss: 0.0338 - distillation_loss: 0.0000e+00
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0331 - student_loss: 0.0322 - distillation_loss: 0.0000e+00
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0318 - student_loss: 0.0310 - distillation_loss: 0.0000e+00
# Epoch 35/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0312 - student_loss: 0.0321 - distillation_loss: 0.0000e+00
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0312 - student_loss: 0.0312 - distillation_loss: 0.0000e+00
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0298 - student_loss: 0.0294 - distillation_loss: 0.0000e+00
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0284 - student_loss: 0.0294 - distillation_loss: 0.0000e+00
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0282 - student_loss: 0.0281 - distillation_loss: 0.0000e+00
# Epoch 40/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0273 - student_loss: 0.0272 - distillation_loss: 0.0000e+00
# Epoch 41/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0276 - student_loss: 0.0265 - distillation_loss: 0.0000e+00
# Epoch 42/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0263 - student_loss: 0.0274 - distillation_loss: 0.0000e+00
# Epoch 43/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0260 - student_loss: 0.0268 - distillation_loss: 0.0000e+00
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0247 - student_loss: 0.0243 - distillation_loss: 0.0000e+00
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0246 - student_loss: 0.0246 - distillation_loss: 0.0000e+00
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0245 - student_loss: 0.0236 - distillation_loss: 0.0000e+00
# Epoch 47/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0235 - student_loss: 0.0223 - distillation_loss: 0.0000e+00
# Epoch 48/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0225 - student_loss: 0.0219 - distillation_loss: 0.0000e+00
# Epoch 49/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0226 - student_loss: 0.0223 - distillation_loss: 0.0000e+00
# Epoch 50/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0219 - student_loss: 0.0251 - distillation_loss: 0.0000e+00
# Epoch 51/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0221 - student_loss: 0.0213 - distillation_loss: 0.0000e+00
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0215 - student_loss: 0.0216 - distillation_loss: 0.0000e+00
# Epoch 53/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0215 - student_loss: 0.0224 - distillation_loss: 0.0000e+00
# Epoch 54/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0214 - student_loss: 0.0234 - distillation_loss: 0.0000e+00
# Epoch 55/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0206 - student_loss: 0.0204 - distillation_loss: 0.0000e+00
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0206 - student_loss: 0.0198 - distillation_loss: 0.0000e+00
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0194 - student_loss: 0.0196 - distillation_loss: 0.0000e+00
# Epoch 58/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0199 - student_loss: 0.0191 - distillation_loss: 0.0000e+00
# Epoch 59/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0184 - student_loss: 0.0208 - distillation_loss: 0.0000e+00
# Epoch 60/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0196 - student_loss: 0.0190 - distillation_loss: 0.0000e+00
# Epoch 61/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0182 - student_loss: 0.0172 - distillation_loss: 0.0000e+00
# Epoch 62/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0189 - student_loss: 0.0186 - distillation_loss: 0.0000e+00
# Epoch 63/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0183 - student_loss: 0.0185 - distillation_loss: 0.0000e+00
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0182 - student_loss: 0.0173 - distillation_loss: 0.0000e+00
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0178 - student_loss: 0.0172 - distillation_loss: 0.0000e+00
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0172 - student_loss: 0.0180 - distillation_loss: 0.0000e+00
# Epoch 67/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0174 - student_loss: 0.0165 - distillation_loss: 0.0000e+00
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0173 - student_loss: 0.0173 - distillation_loss: 0.0000e+00
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0165 - student_loss: 0.0160 - distillation_loss: 0.0000e+00
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0163 - student_loss: 0.0155 - distillation_loss: 0.0000e+00
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0163 - student_loss: 0.0154 - distillation_loss: 0.0000e+00
# Epoch 72/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0163 - student_loss: 0.0155 - distillation_loss: 0.0000e+00
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0162 - student_loss: 0.0155 - distillation_loss: 0.0000e+00
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0154 - student_loss: 0.0147 - distillation_loss: 0.0000e+00
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0161 - student_loss: 0.0181 - distillation_loss: 0.0000e+00
# Epoch 76/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0154 - student_loss: 0.0161 - distillation_loss: 0.0000e+00
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0175 - student_loss: 0.0193 - distillation_loss: 0.0000e+00
# Epoch 78/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0166 - student_loss: 0.0166 - distillation_loss: 0.0000e+00
# Epoch 79/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0149 - student_loss: 0.0147 - distillation_loss: 0.0000e+00
# Epoch 80/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0153 - student_loss: 0.0156 - distillation_loss: 0.0000e+00
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0147 - student_loss: 0.0139 - distillation_loss: 0.0000e+00
# Epoch 82/100
# 32/32 [==============================] - 0s 3ms/step - mean_squared_error: 0.0147 - student_loss: 0.0142 - distillation_loss: 0.0000e+00
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0144 - student_loss: 0.0167 - distillation_loss: 0.0000e+00
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0152 - student_loss: 0.0150 - distillation_loss: 0.0000e+00
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0149 - student_loss: 0.0141 - distillation_loss: 0.0000e+00
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0139 - student_loss: 0.0138 - distillation_loss: 0.0000e+00
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0136 - student_loss: 0.0145 - distillation_loss: 0.0000e+00
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0139 - student_loss: 0.0137 - distillation_loss: 0.0000e+00
# Epoch 89/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0140 - student_loss: 0.0136 - distillation_loss: 0.0000e+00
# Epoch 90/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0141 - student_loss: 0.0136 - distillation_loss: 0.0000e+00
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0136 - student_loss: 0.0155 - distillation_loss: 0.0000e+00
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0151 - student_loss: 0.0148 - distillation_loss: 0.0000e+00
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0133 - student_loss: 0.0127 - distillation_loss: 0.0000e+00
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0127 - student_loss: 0.0121 - distillation_loss: 0.0000e+00
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0128 - student_loss: 0.0140 - distillation_loss: 0.0000e+00
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0129 - student_loss: 0.0126 - distillation_loss: 0.0000e+00
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0142 - student_loss: 0.0135 - distillation_loss: 0.0000e+00
# Epoch 98/100
# 32/32 [==============================] - 0s 2ms/step - mean_squared_error: 0.0123 - student_loss: 0.0123 - distillation_loss: 0.0000e+00
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0140 - student_loss: 0.0133 - distillation_loss: 0.0000e+00
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - mean_squared_error: 0.0124 - student_loss: 0.0119 - distillation_loss: 0.0000e+00

# %%
student_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 10)                30
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 10)                110
#
#  dense_15 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________

# %%
X = np.linspace(-2,2,100)
Y = X.copy()
xx,yy = np.meshgrid(X,Y)
labels = student_model.predict(np.c_[xx.ravel(), yy.ravel()])
z = labels.reshape(xx.shape)
 
plt.contour(xx,yy,z, label="Prediction (large)")
plt.scatter(inputs[0], inputs[1], c=outputs[0], marker=".", label="original data")
plt.legend()
plt.title("Prediction of large network over original data")
plt.xlabel("Input 0")
plt.ylabel("Input 1")
plt.show()
# Out:
# 313/313 [==============================] - 0s 755us/step
# /var/folders/3g/8436y4yj1r9367dvt15y6jqcdx0hcv/T/ipykernel_61116/635805078.py:7: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xx,yy,z, label="Prediction (large)")

# %% [markdown]
# # Verify both networks
#
# Assert that the decision is correct inside each quadrant (with some padding)?
#
# Constant Padding
# - Q1: Input 0 > 0.5 and Input 1 > 0.5 => Output 0 == False
# - Q2: Input 0 > 0.5 and Input 1 < -0.5 => Output 0 == True
# - Q3: Input 0 < -0.5 and Input 1 < -0.5 => Output 0 == False
# - Q4: Input 0 > 0.5 and Input 1 < -0.5 => Output 0 == True
#
# Proportional Padding
# - Q1: Input 0 > 1/1000 * Input 1 and Input 1 > 1/1000 * Input 0 => Output 0 == False
# - Q2: Input 0 > 1/1000 * Input 1 and Input 1 < -1/1000 * Input 0 == True
# - Q3: Input 0 < -1/1000 * Input 1 and Input 1 < -1/1000 * Input 0 == False
# - Q4: Input 0 > 1/1000 * Input 1 and Input 1 < -1/1000 * Input 0 == True
#
# ## Data Driven Method
# Ensure that every data point in the dataset satisfying the preconditions evaluate to the correct output.

# %%
padding = 0.5

# This property list is of the format:
# (Name of property, region of input for which it must apply, output value
properties = (
    ("Q1", inputs[:,(inputs[0] > padding) & (inputs[1] > padding)], False),
    ("Q2", inputs[:,(inputs[0] < -padding) & (inputs[1] > padding)], True),
    ("Q3", inputs[:,(inputs[0] < -padding) & (inputs[1] < -padding)], False),
    ("Q4", inputs[:,(inputs[0] > padding) & (inputs[1] < -padding)], True),
)

for model_name, the_model in [("student", student_model), ("teacher", model)]:
    print(f"Inspecting {model_name}")
    for property_name, property_data, property_output in properties:
        prediction = the_model.predict(property_data.T)
        assert (np.abs(prediction - property_output)<0.1).all() , f"{property_name} failed"
        print(f"Model {model_name}, {property_name} property passed!")
# Out:
# Inspecting student
# 2/2 [==============================] - 0s 2ms/step
# Model student, Q1 property passed!
# 3/3 [==============================] - 0s 1ms/step
# Model student, Q2 property passed!
# 2/2 [==============================] - 0s 2ms/step
# Model student, Q3 property passed!
# 2/2 [==============================] - 0s 2ms/step
# Model student, Q4 property passed!
# Inspecting teacher
# 2/2 [==============================] - 0s 2ms/step
# Model teacher, Q1 property passed!
# 3/3 [==============================] - 0s 2ms/step
# Model teacher, Q2 property passed!
# 2/2 [==============================] - 0s 2ms/step
# Model teacher, Q3 property passed!
# 2/2 [==============================] - 0s 2ms/step
# Model teacher, Q4 property passed!

# %% [markdown]
# ## Probabilistic Method
# Ensure that a random samples from within the precondition produce the correct output.

# %%
padding = 0.1
max_distance = 2.0
samples = 1000

# This property list is of the format:
# (Name of property, region of input for which it must apply, output value
properties = [
    ("Q1", np.array([np.random.uniform(padding, max_distance, samples),
                    np.random.uniform(padding,max_distance,samples)]), False)
]

for model_name, the_model in [("student", student_model), ("teacher", model)]:
    print(f"Inspecting {model_name}")
    for property_name, property_data, property_output in properties:
        prediction = the_model.predict(property_data.T)
        errors = (np.abs(prediction - property_output) < 0.1)
        if not errors.all():
            print(f"{property_name} failed")
            print(property_data[:,errors.flatten()==False])
            continue
        print(f"Model {model_name}, {property_name} property passed!")
# Out:
# Inspecting student
# 32/32 [==============================] - 0s 905us/step
# Q1 failed
# [[0.16280821 0.10730624 0.15013088 0.18844997 0.12282287 0.14237667
#   0.15970728 0.11238123 0.13092208 0.16391227 0.10960316 0.17815483]
#  [1.84605987 1.50029784 1.76233046 1.93190365 1.66620002 1.75117752
#   1.94980456 1.78440209 1.62117722 1.83889898 1.99532047 1.98631881]]
# Inspecting teacher
# 32/32 [==============================] - 0s 865us/step
# Q1 failed
# [[1.9970791 ]
#  [0.10328627]]

# %% [markdown]
# ## Analytic Method
# Ensure that all points within the precondition produce the correct output.
#
# ### Using abstraction
# ### Complete

# %% [markdown]
# ## NNenum

# %%
tf.saved_model.save(student_model, "./distill_test_student_model")
tf.saved_model.save(model, "./distill_test_model")
# Out:
# INFO:tensorflow:Assets written to: ./distill_test_student_model/assets
# INFO:tensorflow:Assets written to: ./distill_test_model/assets

# %%
# !python -m tf2onnx.convert --saved-model ./distill_test_model/ --output distill_test_model.onnx --opset 11
# !python -m tf2onnx.convert --saved-model ./distill_test_student_model/ --output distill_test_student_model.onnx --opset 11
# Out:
# /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2022-07-08 11:46:08,182 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2022-07-08 11:46:08,413 - INFO - Signatures found in model: [serving_default].
# 2022-07-08 11:46:08,413 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2022-07-08 11:46:08,413 - INFO - Output names: ['dense_11']
# WARNING:tensorflow:From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:46:08,476 - WARNING - From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:46:08,495 - INFO - Using tensorflow=2.9.1, onnx=1.12.0, tf2onnx=1.11.1/1915fb
# 2022-07-08 11:46:08,496 - INFO - Using opset <onnx, 11>
# 2022-07-08 11:46:08,510 - INFO - Computed 0 values for constant folding
# 2022-07-08 11:46:08,527 - INFO - Optimizing ONNX model
# 2022-07-08 11:46:08,581 - INFO - After optimization: Identity -5 (5->0)
# 2022-07-08 11:46:08,584 - INFO -
# 2022-07-08 11:46:08,585 - INFO - Successfully converted TensorFlow model ./distill_test_model/ to ONNX
# 2022-07-08 11:46:08,585 - INFO - Model inputs: ['dense_8_input']
# 2022-07-08 11:46:08,585 - INFO - Model outputs: ['dense_11']
# 2022-07-08 11:46:08,585 - INFO - ONNX model is saved at distill_test_model.onnx
# /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2022-07-08 11:46:12,646 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2022-07-08 11:46:12,835 - INFO - Signatures found in model: [serving_default].
# 2022-07-08 11:46:12,835 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2022-07-08 11:46:12,835 - INFO - Output names: ['dense_15']
# WARNING:tensorflow:From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:46:12,894 - WARNING - From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:46:12,910 - INFO - Using tensorflow=2.9.1, onnx=1.12.0, tf2onnx=1.11.1/1915fb
# 2022-07-08 11:46:12,910 - INFO - Using opset <onnx, 11>
# 2022-07-08 11:46:12,921 - INFO - Computed 0 values for constant folding
# 2022-07-08 11:46:12,937 - INFO - Optimizing ONNX model
# 2022-07-08 11:46:12,993 - INFO - After optimization: Identity -5 (5->0)
# 2022-07-08 11:46:12,996 - INFO -
# 2022-07-08 11:46:12,996 - INFO - Successfully converted TensorFlow model ./distill_test_student_model/ to ONNX
# 2022-07-08 11:46:12,996 - INFO - Model inputs: ['dense_12_input']
# 2022-07-08 11:46:12,997 - INFO - Model outputs: ['dense_15']
# 2022-07-08 11:46:12,997 - INFO - ONNX model is saved at distill_test_student_model.onnx

# %%
property = """
; Q1 Property

(declare-const X_0 Real)
(declare-const X_1 Real)

(declare-const Y_0 Real)
(declare-const Y_1 Real)
(declare-const Y_2 Real)
(declare-const Y_3 Real)


(assert (>= X_0 0.2))
(assert (<= X_0 1000.0))
(assert (>= X_1 0.2))
(assert (<= X_1 1000.0))

(assert (>= Y_0 0.5))
"""

with open("distill_test.vnnlib", "w") as file:
    file.write(property)

# %%
# !docker run -it -v $(PWD):/my_work nnenum_image python3 -m nnenum.nnenum /my_work/distill_test_model.onnx /my_work/distill_test.vnnlib
# Out:
# all input names: ['dense_8_input', 'StatefulPartitionedCall/sequential_2/dense_8/MatMul/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_8/MatMul:0', 'StatefulPartitionedCall/sequential_2/dense_8/BiasAdd/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_8/BiasAdd:0', 'StatefulPartitionedCall/sequential_2/dense_8/Relu:0', 'StatefulPartitionedCall/sequential_2/dense_9/MatMul/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_9/MatMul:0', 'StatefulPartitionedCall/sequential_2/dense_9/BiasAdd/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_9/BiasAdd:0', 'StatefulPartitionedCall/sequential_2/dense_9/Relu:0', 'StatefulPartitionedCall/sequential_2/dense_10/MatMul/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_10/MatMul:0', 'StatefulPartitionedCall/sequential_2/dense_10/BiasAdd/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_10/BiasAdd:0', 'StatefulPartitionedCall/sequential_2/dense_10/Relu:0', 'StatefulPartitionedCall/sequential_2/dense_11/MatMul/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_11/MatMul:0', 'StatefulPartitionedCall/sequential_2/dense_11/BiasAdd/ReadVariableOp:0', 'StatefulPartitionedCall/sequential_2/dense_11/BiasAdd:0']
# Running in parallel with 6 processes
# (0.0 sec) Q: 0, Sets: 0/1  (0.0%) ETA: - (expected 1 stars)
# (0.1 sec) Q: 2, Sets: 7/14  (24.268%) ETA: 0.5 sec (expected 29 stars)
# (0.4 sec) Q: 0, Sets: 88/99  (89.526%) ETA: 0.0 sec (expected 98 stars)
# Found unsafe from first concrete execution of abstract counterexample
#
# violation star found a confirmed counterexample.
#
# Unsafe Base Branch: +---++--- (Mode: 0)
#
#
#
# Total Stars: 110 (24 exact, 86 approx)
# Runtime: 0.5 sec
# Completed work frac: 0.9755859375
# Num Stars Copied Between Processes: 35
# Num Lps During Enumeration: 983
# Total Num Lps: 983
#
# Result: network is UNSAFE with confirmed counterexample in result.cinput and result.coutput
# Input: [1000.0, 1.5556272268295288]
# Output: [0.591354489326477]
