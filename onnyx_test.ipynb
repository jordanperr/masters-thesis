# %%
from re import L
import onnx
import onnxruntime
import onnx_tf


model = onnx.load("/Users/jperrsau/cu-src/thesis/src/nnenum/examples/acasxu/data/ACASXU_run2a_1_1_batch_2000.onnx")


for node in model.graph.node:
    print(node)

#tf_model = onnx_tf.backend.prepare(model)


# import  tensorflow as tf

# model = tf.saved_model.load("./data/acasxu/ACASXU_run2a_1_1_batch_2000.pb")

# print(model)
# Out:
# input: "input"
# input: "input_AvgImg"
# output: "input_Sub"
# name: "input_Sub"
# op_type: "Sub"
#
# input: "input_Sub"
# output: "Operation_1_Flatten"
# name: "Operation_1_Flatten"
# op_type: "Flatten"
# attribute {
#   name: "axis"
#   i: 1
#   type: INT
# }
#
# input: "Operation_1_Flatten"
# input: "Operation_1_MatMul_W"
# output: "Operation_1_MatMul"
# name: "Operation_1_MatMul"
# op_type: "MatMul"
#
# input: "Operation_1_MatMul"
# input: "Operation_1_Add_B"
# output: "Operation_1_Add"
# name: "Operation_1_Add"
# op_type: "Add"
#
# input: "Operation_1_Add"
# output: "relu_1"
# name: "relu_1"
# op_type: "Relu"
#
# input: "relu_1"
# input: "Operation_2_MatMul_W"
# output: "Operation_2_MatMul"
# name: "Operation_2_MatMul"
# op_type: "MatMul"
#
# input: "Operation_2_MatMul"
# input: "Operation_2_Add_B"
# output: "Operation_2_Add"
# name: "Operation_2_Add"
# op_type: "Add"
#
# input: "Operation_2_Add"
# output: "relu_2"
# name: "relu_2"
# op_type: "Relu"
#
# input: "relu_2"
# input: "Operation_3_MatMul_W"
# output: "Operation_3_MatMul"
# name: "Operation_3_MatMul"
# op_type: "MatMul"
#
# input: "Operation_3_MatMul"
# input: "Operation_3_Add_B"
# output: "Operation_3_Add"
# name: "Operation_3_Add"
# op_type: "Add"
#
# input: "Operation_3_Add"
# output: "relu_3"
# name: "relu_3"
# op_type: "Relu"
#
# input: "relu_3"
# input: "Operation_4_MatMul_W"
# output: "Operation_4_MatMul"
# name: "Operation_4_MatMul"
# op_type: "MatMul"
#
# input: "Operation_4_MatMul"
# input: "Operation_4_Add_B"
# output: "Operation_4_Add"
# name: "Operation_4_Add"
# op_type: "Add"
#
# input: "Operation_4_Add"
# output: "relu_4"
# name: "relu_4"
# op_type: "Relu"
#
# input: "relu_4"
# input: "Operation_5_MatMul_W"
# output: "Operation_5_MatMul"
# name: "Operation_5_MatMul"
# op_type: "MatMul"
#
# input: "Operation_5_MatMul"
# input: "Operation_5_Add_B"
# output: "Operation_5_Add"
# name: "Operation_5_Add"
# op_type: "Add"
#
# input: "Operation_5_Add"
# output: "relu_5"
# name: "relu_5"
# op_type: "Relu"
#
# input: "relu_5"
# input: "Operation_6_MatMul_W"
# output: "Operation_6_MatMul"
# name: "Operation_6_MatMul"
# op_type: "MatMul"
#
# input: "Operation_6_MatMul"
# input: "Operation_6_Add_B"
# output: "Operation_6_Add"
# name: "Operation_6_Add"
# op_type: "Add"
#
# input: "Operation_6_Add"
# output: "relu_6"
# name: "relu_6"
# op_type: "Relu"
#
# input: "relu_6"
# input: "linear_7_MatMul_W"
# output: "linear_7_MatMul"
# name: "linear_7_MatMul"
# op_type: "MatMul"
#
# input: "linear_7_MatMul"
# input: "linear_7_Add_B"
# output: "linear_7_Add"
# name: "linear_7_Add"
# op_type: "Add"
