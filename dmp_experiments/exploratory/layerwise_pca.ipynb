# %% [markdown]
# Experiments with interpretability metrics such as
# - Concept Activation Vectors (CAV)
# - Network Dissection
# - PCA / Other Clustering of intermediate layers.
#
# Hypothesis:
# - Unlike CNNs, DNNs will show very little, if any, heirarchical features in their hidden units. This is because there is no spatial dependence in a FCNN, and so each layer of the heirarchy contains no more or less global information than the previous layers.
# - There will be a greater proportion of interpretable neurons in a right-sized neural network. And these networks will be less entangled and have clearer concept activation vectors.
#
# - Monte: Can we find common weight subsets between two networks. Growing network.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dmp.data.pmlb import pmlb_loader
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

import sys
sys.path.append("..")

from networks import get_basic_537_houses
from viz import *

# %%
model, inputs, outputs = get_basic_537_houses(num_hidden_layers=6, hidden_layer_width=128)
# Out:
# (20640, 8)
# array([[0.90226638],
#        [0.70824656],
#        [0.69505074],
#        ...,
#        [0.15938285],
#        [0.14371281],
#        [0.15340349]])
# (20640, 1)
# num_observations 20640 num_inputs 8 num_outputs 1
# Epoch 1/100
# 65/65 [==============================] - 1s 5ms/step - loss: 0.0454 - val_loss: 0.0190
# Epoch 2/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0206
# Epoch 3/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0182
# Epoch 4/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0172
# Epoch 5/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0172
# Epoch 6/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0153 - val_loss: 0.0168
# Epoch 7/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0184
# Epoch 8/100
# ...

# %%
print_layer_pca(model, inputs, outputs)
