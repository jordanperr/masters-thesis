# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

# %% [markdown]
# # Second Example: Quadrant Identification Distillation and Verification
#
# In this notebook, we demonstrate network distillation and verification using a quadrant detection dataset. This was inspired by the XOR dataset notebook, but we are adding more categories because I suspect the softmax loss function in the distillation class is not working correctly for a binary classification. If this notebook is successful, I would like to add regression and binary classification capability to network distillation class. First, we train an overparametrized network on the dataset, graphing the decision boundary. Next we distill this network using Hinton distillation. Finally, we verify both networks using nnenum to check that the decision is stable within a certain region.

# %% [markdown]
# ## The Quadrant dataset
# Here is the dataset we will train with. It includes 1000 uniformly distributed samples of the quadrant function within the region (-1,1) of the $\mathbb{R}^2$ plane.

# %%
def dataset_quadrant_uniform(n=1000):
    inputs = np.random.random((2,n))*2-1
    condlist = [(inputs[0] > 0) & (inputs[1] > 0),
            (inputs[0] > 0) & (inputs[1] < 0),
            (inputs[0] < 0) & (inputs[1] < 0),
            (inputs[0] < 0) & (inputs[1] > 0)
    ]
    choicelist = [0,1,2,3]
    outputs = np.select(condlist, choicelist, default='unknown').astype('int')
    return inputs, outputs

choicelist = [0,1,2,3]
inputs, outputs = dataset_quadrant_uniform()

# %%
colorlist = {0:"blue", 1:"green", 2:"red", 3:"purple"}

for choice in choicelist:
    points = outputs.flatten() == choice
    plt.scatter(inputs[0,points], inputs[1,points], c=colorlist[choice])
plt.title("Uniform XOR Dataset (n=1000)")
plt.xlabel("Input 0")
plt.ylabel("Input 1")
plt.show()

# %% [markdown]
# ## Train teacher network
#
# Now, train a fully connected neural network on this dataset with ~5,000 free parameters for 100 epochs.

# %%
(inputs.shape, outputs.shape)
outputs_one_hot = tf.keras.utils.to_categorical(outputs)

# %%
num_observations = inputs.shape[1]
num_inputs = inputs.shape[0]
#num_outputs = 4
num_outputs = outputs_one_hot.shape[1]

hidden_layer_width=50
num_hidden_layers=3

## Input Layer
layers = [
    tf.keras.layers.Dense(
        hidden_layer_width,
        activation=tf.nn.relu,
        input_shape=(num_inputs,),
        kernel_initializer=tf.keras.initializers.GlorotUniform(),
        bias_initializer=tf.keras.initializers.GlorotUniform()
    )
]

## Hidden Layers
for i in range(num_hidden_layers-1):
    layers.append(
        tf.keras.layers.Dense(hidden_layer_width,
            activation=tf.nn.relu,
            kernel_initializer=tf.keras.initializers.GlorotUniform(),
            bias_initializer=tf.keras.initializers.GlorotUniform())
    )

## Output Layer
layers.append(tf.keras.layers.Dense(num_outputs))

model = tf.keras.Sequential(layers)

model.compile(
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
optimizer=tf.keras.optimizers.Adam(0.001),
)

model.summary()

model.fit(
    x=inputs.T,
    y=outputs,
    shuffle=True,
    validation_split=.2,
    epochs=250,
    batch_size=128,
    )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 50)                150
#
#  dense_5 (Dense)             (None, 50)                2550
#
#  dense_6 (Dense)             (None, 50)                2550
#
#  dense_7 (Dense)             (None, 4)                 204
#
# =================================================================
# Total params: 5,454
# Trainable params: 5,454
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 7/7 [==============================] - 1s 23ms/step - loss: 1.3303 - sparse_categorical_accuracy: 0.4100 - val_loss: 1.2761 - val_sparse_categorical_accuracy: 0.6050
# Epoch 2/250
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2398 - sparse_categorical_accuracy: 0.7362 - val_loss: 1.1914 - val_sparse_categorical_accuracy: 0.8250
# Epoch 3/250
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1495 - sparse_categorical_accuracy: 0.8625 - val_loss: 1.1019 - val_sparse_categorical_accuracy: 0.8250
# Epoch 4/250
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0513 - sparse_categorical_accuracy: 0.8550 - val_loss: 1.0027 - val_sparse_categorical_accuracy: 0.8250
# Epoch 5/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9462 - sparse_categorical_accuracy: 0.8838 - val_loss: 0.8903 - val_sparse_categorical_accuracy: 0.8600
# Epoch 6/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8304 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.7711 - val_sparse_categorical_accuracy: 0.8850
# Epoch 7/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7120 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.6479 - val_sparse_categorical_accuracy: 0.9400
# Epoch 8/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5939 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.5330 - val_sparse_categorical_accuracy: 0.9550
# Epoch 9/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4865 - sparse_categorical_accuracy: 0.9550 - val_loss: 0.4310 - val_sparse_categorical_accuracy: 0.9750
# Epoch 10/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3959 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.3503 - val_sparse_categorical_accuracy: 0.9800
# Epoch 11/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3256 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.2916 - val_sparse_categorical_accuracy: 0.9800
# Epoch 12/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2759 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.2489 - val_sparse_categorical_accuracy: 0.9800
# Epoch 13/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2380 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.2178 - val_sparse_categorical_accuracy: 0.9750
# Epoch 14/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2102 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1929 - val_sparse_categorical_accuracy: 0.9750
# Epoch 15/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1875 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.1725 - val_sparse_categorical_accuracy: 0.9800
# Epoch 16/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1716 - sparse_categorical_accuracy: 0.9762 - val_loss: 0.1572 - val_sparse_categorical_accuracy: 0.9750
# Epoch 17/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1574 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.1463 - val_sparse_categorical_accuracy: 0.9750
# Epoch 18/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1458 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.1403 - val_sparse_categorical_accuracy: 0.9750
# Epoch 19/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1385 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.1308 - val_sparse_categorical_accuracy: 0.9750
# Epoch 20/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1291 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.1164 - val_sparse_categorical_accuracy: 0.9950
# Epoch 21/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1241 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.1135 - val_sparse_categorical_accuracy: 0.9900
# Epoch 22/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1181 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.1113 - val_sparse_categorical_accuracy: 0.9750
# Epoch 23/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1106 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0977 - val_sparse_categorical_accuracy: 0.9950
# Epoch 24/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1069 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0948 - val_sparse_categorical_accuracy: 0.9900
# Epoch 25/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1028 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.0959 - val_sparse_categorical_accuracy: 0.9750
# Epoch 26/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0980 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9850
# Epoch 27/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0827 - val_sparse_categorical_accuracy: 0.9900
# Epoch 28/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0909 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0774 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0883 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0779 - val_sparse_categorical_accuracy: 0.9850
# Epoch 30/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0863 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0803 - val_sparse_categorical_accuracy: 0.9850
# Epoch 31/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0826 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0698 - val_sparse_categorical_accuracy: 0.9950
# Epoch 32/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0806 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0717 - val_sparse_categorical_accuracy: 0.9850
# Epoch 33/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0785 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0702 - val_sparse_categorical_accuracy: 0.9900
# Epoch 34/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0631 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0742 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0610 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0727 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0646 - val_sparse_categorical_accuracy: 0.9900
# Epoch 37/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0623 - val_sparse_categorical_accuracy: 0.9900
# Epoch 38/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0704 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0589 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0572 - val_sparse_categorical_accuracy: 0.9950
# Epoch 40/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0534 - val_sparse_categorical_accuracy: 0.9950
# Epoch 41/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0664 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 0.9950
# Epoch 42/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0634 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0601 - val_sparse_categorical_accuracy: 0.9850
# Epoch 43/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.0537 - val_sparse_categorical_accuracy: 0.9850
# Epoch 44/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0543 - val_sparse_categorical_accuracy: 0.9950
# Epoch 45/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0608 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0490 - val_sparse_categorical_accuracy: 0.9950
# Epoch 46/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0581 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0493 - val_sparse_categorical_accuracy: 0.9950
# Epoch 47/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0565 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0506 - val_sparse_categorical_accuracy: 0.9900
# Epoch 48/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0568 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0520 - val_sparse_categorical_accuracy: 0.9950
# Epoch 49/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0458 - val_sparse_categorical_accuracy: 0.9950
# Epoch 50/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0569 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0467 - val_sparse_categorical_accuracy: 0.9900
# Epoch 51/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0525 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0470 - val_sparse_categorical_accuracy: 0.9900
# Epoch 52/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0517 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0440 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0430 - val_sparse_categorical_accuracy: 1.0000
# Epoch 54/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0493 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0491 - val_sparse_categorical_accuracy: 0.9900
# Epoch 55/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0427 - val_sparse_categorical_accuracy: 0.9900
# Epoch 56/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0507 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0390 - val_sparse_categorical_accuracy: 0.9950
# Epoch 57/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0491 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0498 - val_sparse_categorical_accuracy: 0.9900
# Epoch 58/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0467 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0363 - val_sparse_categorical_accuracy: 1.0000
# Epoch 59/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0351 - val_sparse_categorical_accuracy: 1.0000
# Epoch 60/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0469 - val_sparse_categorical_accuracy: 0.9800
# Epoch 61/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0466 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0373 - val_sparse_categorical_accuracy: 1.0000
# Epoch 62/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0356 - val_sparse_categorical_accuracy: 0.9950
# Epoch 63/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0444 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0377 - val_sparse_categorical_accuracy: 0.9950
# Epoch 64/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0384 - val_sparse_categorical_accuracy: 0.9900
# Epoch 65/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0320 - val_sparse_categorical_accuracy: 0.9950
# Epoch 66/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0376 - val_sparse_categorical_accuracy: 0.9950
# Epoch 67/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0363 - val_sparse_categorical_accuracy: 1.0000
# Epoch 68/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0323 - val_sparse_categorical_accuracy: 1.0000
# Epoch 69/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0333 - val_sparse_categorical_accuracy: 1.0000
# Epoch 70/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0406 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0375 - val_sparse_categorical_accuracy: 0.9950
# Epoch 71/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0349 - val_sparse_categorical_accuracy: 1.0000
# Epoch 72/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0410 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0314 - val_sparse_categorical_accuracy: 1.0000
# Epoch 73/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0362 - val_sparse_categorical_accuracy: 1.0000
# Epoch 74/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0411 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0355 - val_sparse_categorical_accuracy: 0.9950
# Epoch 75/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0409 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0342 - val_sparse_categorical_accuracy: 0.9950
# Epoch 76/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0289 - val_sparse_categorical_accuracy: 1.0000
# Epoch 77/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0335 - val_sparse_categorical_accuracy: 0.9950
# Epoch 78/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0356 - val_sparse_categorical_accuracy: 0.9850
# Epoch 79/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0289 - val_sparse_categorical_accuracy: 1.0000
# Epoch 80/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0363 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0320 - val_sparse_categorical_accuracy: 0.9950
# Epoch 81/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0294 - val_sparse_categorical_accuracy: 0.9950
# Epoch 82/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0364 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0279 - val_sparse_categorical_accuracy: 1.0000
# Epoch 83/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0282 - val_sparse_categorical_accuracy: 0.9950
# Epoch 84/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0277 - val_sparse_categorical_accuracy: 0.9950
# Epoch 85/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0331 - val_sparse_categorical_accuracy: 0.9900
# Epoch 86/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0343 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0271 - val_sparse_categorical_accuracy: 1.0000
# Epoch 87/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0354 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9950
# Epoch 88/250
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0351 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0296 - val_sparse_categorical_accuracy: 0.9950
# Epoch 89/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0276 - val_sparse_categorical_accuracy: 0.9950
# Epoch 90/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0301 - val_sparse_categorical_accuracy: 0.9950
# Epoch 91/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9950
# Epoch 92/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 0.9950
# Epoch 93/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0319 - val_sparse_categorical_accuracy: 0.9900
# Epoch 94/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0342 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0287 - val_sparse_categorical_accuracy: 1.0000
# Epoch 95/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0322 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0237 - val_sparse_categorical_accuracy: 0.9950
# Epoch 96/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0311 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0256 - val_sparse_categorical_accuracy: 1.0000
# Epoch 97/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0256 - val_sparse_categorical_accuracy: 1.0000
# Epoch 98/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0298 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0240 - val_sparse_categorical_accuracy: 1.0000
# Epoch 99/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0255 - val_sparse_categorical_accuracy: 0.9950
# Epoch 100/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0304 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0258 - val_sparse_categorical_accuracy: 1.0000
# Epoch 101/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0254 - val_sparse_categorical_accuracy: 0.9950
# Epoch 102/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0245 - val_sparse_categorical_accuracy: 0.9950
# Epoch 103/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0263 - val_sparse_categorical_accuracy: 1.0000
# Epoch 104/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0294 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 0.9950
# Epoch 105/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0253 - val_sparse_categorical_accuracy: 0.9950
# Epoch 106/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 1.0000
# Epoch 107/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9950
# Epoch 108/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0249 - val_sparse_categorical_accuracy: 1.0000
# Epoch 109/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0230 - val_sparse_categorical_accuracy: 0.9950
# Epoch 110/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 0.9950
# Epoch 111/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0242 - val_sparse_categorical_accuracy: 0.9950
# Epoch 112/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9950
# Epoch 113/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0286 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 1.0000
# Epoch 114/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0244 - val_sparse_categorical_accuracy: 1.0000
# Epoch 115/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0229 - val_sparse_categorical_accuracy: 0.9950
# Epoch 116/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0272 - val_sparse_categorical_accuracy: 0.9900
# Epoch 117/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0214 - val_sparse_categorical_accuracy: 0.9950
# Epoch 118/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0206 - val_sparse_categorical_accuracy: 1.0000
# Epoch 119/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0256 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0249 - val_sparse_categorical_accuracy: 0.9900
# Epoch 120/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0312 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0259 - val_sparse_categorical_accuracy: 0.9950
# Epoch 121/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0192 - val_sparse_categorical_accuracy: 1.0000
# Epoch 122/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0213 - val_sparse_categorical_accuracy: 1.0000
# Epoch 123/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9950
# Epoch 124/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 1.0000
# Epoch 125/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0208 - val_sparse_categorical_accuracy: 1.0000
# Epoch 126/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 1.0000
# Epoch 127/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0240 - val_sparse_categorical_accuracy: 0.9950
# Epoch 128/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0234 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 0.9950
# Epoch 129/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0273 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9950
# Epoch 130/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 1.0000
# Epoch 131/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 0.9950
# Epoch 132/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0196 - val_sparse_categorical_accuracy: 1.0000
# Epoch 133/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 1.0000
# Epoch 134/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0228 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 1.0000
# Epoch 135/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0217 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 1.0000
# Epoch 136/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0227 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 1.0000
# Epoch 137/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0220 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0167 - val_sparse_categorical_accuracy: 0.9950
# Epoch 138/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9950
# Epoch 139/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 1.0000
# Epoch 140/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0226 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 1.0000
# Epoch 141/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 1.0000
# Epoch 142/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9950
# Epoch 143/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0213 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 1.0000
# Epoch 144/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0202 - val_sparse_categorical_accuracy: 0.9950
# Epoch 145/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0227 - val_sparse_categorical_accuracy: 0.9950
# Epoch 146/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 0.9950
# Epoch 147/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0210 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0167 - val_sparse_categorical_accuracy: 0.9950
# Epoch 148/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0188 - val_sparse_categorical_accuracy: 1.0000
# Epoch 149/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0201 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9950
# Epoch 150/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 1.0000
# Epoch 151/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0201 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 0.9950
# Epoch 152/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0202 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 1.0000
# Epoch 153/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0198 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 1.0000
# Epoch 154/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0142 - val_sparse_categorical_accuracy: 1.0000
# Epoch 155/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0155 - val_sparse_categorical_accuracy: 0.9950
# Epoch 156/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0205 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 0.9950
# Epoch 157/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0137 - val_sparse_categorical_accuracy: 1.0000
# Epoch 158/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0213 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0136 - val_sparse_categorical_accuracy: 1.0000
# Epoch 159/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0202 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9950
# Epoch 160/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0192 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0143 - val_sparse_categorical_accuracy: 0.9950
# Epoch 161/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0201 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0133 - val_sparse_categorical_accuracy: 1.0000
# Epoch 162/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 0.9950
# Epoch 163/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 1.0000
# Epoch 164/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9950
# Epoch 165/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 0.9950
# Epoch 166/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 1.0000
# Epoch 167/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 1.0000
# Epoch 168/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9950
# Epoch 169/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 1.0000
# Epoch 170/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0139 - val_sparse_categorical_accuracy: 1.0000
# Epoch 171/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0182 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9950
# Epoch 172/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0174 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0146 - val_sparse_categorical_accuracy: 1.0000
# Epoch 173/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0127 - val_sparse_categorical_accuracy: 0.9950
# Epoch 174/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0176 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 1.0000
# Epoch 175/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 0.9950
# Epoch 176/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0124 - val_sparse_categorical_accuracy: 1.0000
# Epoch 177/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0183 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 1.0000
# Epoch 178/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 1.0000
# Epoch 179/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0171 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9950
# Epoch 180/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 1.0000
# Epoch 181/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 1.0000
# Epoch 182/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0280 - val_sparse_categorical_accuracy: 0.9850
# Epoch 183/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0144 - val_sparse_categorical_accuracy: 1.0000
# Epoch 184/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 1.0000
# Epoch 185/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0161 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9900
# Epoch 186/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 0.9950
# Epoch 187/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0223 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9950
# Epoch 188/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0255 - val_sparse_categorical_accuracy: 0.9950
# Epoch 189/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 1.0000
# Epoch 190/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9950
# Epoch 191/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0176 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0138 - val_sparse_categorical_accuracy: 0.9950
# Epoch 192/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9950
# Epoch 193/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 1.0000
# Epoch 194/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0171 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 0.9950
# Epoch 195/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9950
# Epoch 196/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9850
# Epoch 197/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 1.0000
# Epoch 198/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0194 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 0.9950
# Epoch 199/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0142 - val_sparse_categorical_accuracy: 1.0000
# Epoch 200/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 0.9950
# Epoch 201/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0145 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 1.0000
# Epoch 202/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9950
# Epoch 203/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 1.0000
# Epoch 204/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 1.0000
# Epoch 205/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0143 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0123 - val_sparse_categorical_accuracy: 0.9950
# Epoch 206/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0148 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 1.0000
# Epoch 207/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0101 - val_sparse_categorical_accuracy: 1.0000
# Epoch 208/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 1.0000
# Epoch 209/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 0.9950
# Epoch 210/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 1.0000
# Epoch 211/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0114 - val_sparse_categorical_accuracy: 1.0000
# Epoch 212/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0136 - val_sparse_categorical_accuracy: 0.9950
# Epoch 213/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 214/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 215/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0131 - val_sparse_categorical_accuracy: 1.0000
# Epoch 216/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 1.0000
# Epoch 217/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0107 - val_sparse_categorical_accuracy: 1.0000
# Epoch 218/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9950
# Epoch 219/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0136 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0095 - val_sparse_categorical_accuracy: 1.0000
# Epoch 220/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 221/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 1.0000
# Epoch 222/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0144 - val_sparse_categorical_accuracy: 0.9950
# Epoch 223/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0101 - val_sparse_categorical_accuracy: 1.0000
# Epoch 224/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 1.0000
# Epoch 225/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0126 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9950
# Epoch 226/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 1.0000
# Epoch 227/250
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0121 - val_sparse_categorical_accuracy: 1.0000
# Epoch 228/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0161 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0106 - val_sparse_categorical_accuracy: 1.0000
# Epoch 229/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0102 - val_sparse_categorical_accuracy: 0.9950
# Epoch 230/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 0.9950
# Epoch 231/250
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 1.0000
# Epoch 232/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 0.9950
# Epoch 233/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9950
# Epoch 234/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0119 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0110 - val_sparse_categorical_accuracy: 1.0000
# Epoch 235/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 1.0000
# Epoch 236/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0092 - val_sparse_categorical_accuracy: 0.9950
# Epoch 237/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9950
# Epoch 238/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0085 - val_sparse_categorical_accuracy: 0.9950
# Epoch 239/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0085 - val_sparse_categorical_accuracy: 1.0000
# Epoch 240/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0116 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 1.0000
# Epoch 241/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9950
# Epoch 242/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 1.0000
# Epoch 243/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 0.9950
# Epoch 244/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 1.0000
# Epoch 245/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0145 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9950
# Epoch 246/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0080 - val_sparse_categorical_accuracy: 1.0000
# Epoch 247/250
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 1.0000
# Epoch 248/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0108 - val_sparse_categorical_accuracy: 0.9950
# Epoch 249/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0093 - val_sparse_categorical_accuracy: 0.9950
# Epoch 250/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0116 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0081 - val_sparse_categorical_accuracy: 1.0000

# %%
y_pred = model.predict(inputs.T)

X = np.linspace(-2,2,100)
Y = X.copy()
xx,yy = np.meshgrid(X,Y)
labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
labels = np.argmax(labels, axis=1)
z = labels.reshape(xx.shape)

plt.contour(xx,yy,z, label="Prediction (large)")
#plt.scatter(inputs[0], inputs[1], c=outputs[0], marker=".", label="original data")
plt.legend()
plt.title("Prediction of large network over original data")
plt.xlabel("Input 0")
plt.ylabel("Input 1")
plt.show()
# Out:
# 32/32 [==============================] - 0s 852us/step
# 313/313 [==============================] - 0s 749us/step
# /var/folders/3g/8436y4yj1r9367dvt15y6jqcdx0hcv/T/ipykernel_63237/2237265097.py:10: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xx,yy,z, label="Prediction (large)")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# With 20,601 trainable parameters, we are able to get a pretty good decision boundary at least for the in-sample region (-1,1). However, we can see that the network has not learned the exact XOR rule, as evidenced by some unnecessary level curves at the edges of the decision boundary. One may ask the question, does this network faithfully compute XOR throughout the entire $\mathbb{R}^2$ plane?

# %% [markdown]
# ## Train student network using Data-Free Distillation

# %%
## Generate synthetic dataset using a random distribution.

synthetic_inputs = np.random.uniform(-1, 1, (2000,2))
synthetic_outputs = model.predict(synthetic_inputs)

# %%
synthetic_outputs_colors = synthetic_outputs.argmax(axis=1)
for choice in choicelist:
    points = synthetic_outputs_colors.flatten() == choice
    plt.scatter(synthetic_inputs[points,0], synthetic_inputs[points,1], c=colorlist[choice])
plt.title("Synthetic Teacher Outputs (n=2000)")
plt.xlabel("Input 0")
plt.ylabel("Input 1")
plt.show()

# %%
hidden_layer_width=10
num_hidden_layers=3

## Input Layer
layers = [
    tf.keras.layers.Dense(
        hidden_layer_width,
        activation=tf.nn.relu,
        input_shape=(num_inputs,),
        kernel_initializer=tf.keras.initializers.GlorotUniform(),
        bias_initializer=tf.keras.initializers.GlorotUniform()
    )
]

## Hidden Layers
for i in range(num_hidden_layers-1):
    layers.append(
        tf.keras.layers.Dense(hidden_layer_width,
            activation=tf.nn.relu,
            kernel_initializer=tf.keras.initializers.GlorotUniform(),
            bias_initializer=tf.keras.initializers.GlorotUniform())
    )

## Output Layer
layers.append(tf.keras.layers.Dense(num_outputs))

student_model = tf.keras.Sequential(layers)

student_model.summary()

student_model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    #loss=tf.keras.losses.KLDivergence(),
    metrics=[tf.keras.metrics.KLDivergence()],
    optimizer=tf.keras.optimizers.Adam(0.001)
)

student_model.fit(
    x=synthetic_inputs,
    y=synthetic_outputs_colors,#synthetic_outputs, #- Using logits in the loss function requires a different loss metric, like KLDivergence. But I couldn't get it working immediately.
    epochs=100,
    batch_size=128,
    )
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 10)                30
#
#  dense_37 (Dense)            (None, 10)                110
#
#  dense_38 (Dense)            (None, 10)                110
#
#  dense_39 (Dense)            (None, 4)                 44
#
# =================================================================
# Total params: 294
# Trainable params: 294
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3870 - kullback_leibler_divergence: 27.6156
# Epoch 2/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3439 - kullback_leibler_divergence: 23.4807
# Epoch 3/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3048 - kullback_leibler_divergence: 21.7151
# Epoch 4/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.2635 - kullback_leibler_divergence: 22.0797
# Epoch 5/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.2177 - kullback_leibler_divergence: 23.0568
# Epoch 6/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.1678 - kullback_leibler_divergence: 22.8327
# Epoch 7/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.1108 - kullback_leibler_divergence: 22.6309
# Epoch 8/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0449 - kullback_leibler_divergence: 22.3739
# Epoch 9/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9715 - kullback_leibler_divergence: 22.2984
# Epoch 10/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8921 - kullback_leibler_divergence: 22.3378
# Epoch 11/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8089 - kullback_leibler_divergence: 22.2503
# Epoch 12/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7239 - kullback_leibler_divergence: 22.6002
# Epoch 13/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6400 - kullback_leibler_divergence: 22.9546
# Epoch 14/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5565 - kullback_leibler_divergence: 23.1223
# Epoch 15/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4749 - kullback_leibler_divergence: 23.5933
# Epoch 16/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4088 - kullback_leibler_divergence: 23.6213
# Epoch 17/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3579 - kullback_leibler_divergence: 23.9733
# Epoch 18/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3172 - kullback_leibler_divergence: 24.1099
# Epoch 19/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2851 - kullback_leibler_divergence: 24.1423
# Epoch 20/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2575 - kullback_leibler_divergence: 24.3578
# Epoch 21/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2352 - kullback_leibler_divergence: 24.4399
# Epoch 22/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2164 - kullback_leibler_divergence: 24.5626
# Epoch 23/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2006 - kullback_leibler_divergence: 24.6585
# Epoch 24/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1870 - kullback_leibler_divergence: 24.7058
# Epoch 25/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1755 - kullback_leibler_divergence: 24.8423
# Epoch 26/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1648 - kullback_leibler_divergence: 24.9345
# Epoch 27/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1562 - kullback_leibler_divergence: 25.0138
# Epoch 28/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1482 - kullback_leibler_divergence: 25.1036
# Epoch 29/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1414 - kullback_leibler_divergence: 25.1884
# Epoch 30/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1350 - kullback_leibler_divergence: 25.1337
# Epoch 31/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1296 - kullback_leibler_divergence: 25.3830
# Epoch 32/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1241 - kullback_leibler_divergence: 25.4175
# Epoch 33/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1195 - kullback_leibler_divergence: 25.3495
# Epoch 34/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1152 - kullback_leibler_divergence: 25.4955
# Epoch 35/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1110 - kullback_leibler_divergence: 25.4860
# Epoch 36/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1077 - kullback_leibler_divergence: 25.5480
# Epoch 37/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1039 - kullback_leibler_divergence: 25.6284
# Epoch 38/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1009 - kullback_leibler_divergence: 25.6324
# Epoch 39/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0977 - kullback_leibler_divergence: 25.6551
# Epoch 40/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0954 - kullback_leibler_divergence: 25.7062
# Epoch 41/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0929 - kullback_leibler_divergence: 25.7945
# Epoch 42/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0903 - kullback_leibler_divergence: 25.7913
# Epoch 43/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0882 - kullback_leibler_divergence: 25.7878
# Epoch 44/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0864 - kullback_leibler_divergence: 25.9875
# Epoch 45/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0842 - kullback_leibler_divergence: 25.8850
# Epoch 46/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0826 - kullback_leibler_divergence: 25.9216
# Epoch 47/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0801 - kullback_leibler_divergence: 25.9671
# Epoch 48/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0786 - kullback_leibler_divergence: 25.9185
# Epoch 49/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0769 - kullback_leibler_divergence: 26.0463
# Epoch 50/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0755 - kullback_leibler_divergence: 26.0081
# Epoch 51/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0740 - kullback_leibler_divergence: 26.0340
# Epoch 52/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0725 - kullback_leibler_divergence: 26.1533
# Epoch 53/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0716 - kullback_leibler_divergence: 26.0167
# Epoch 54/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0697 - kullback_leibler_divergence: 26.1671
# Epoch 55/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0687 - kullback_leibler_divergence: 26.1260
# Epoch 56/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0675 - kullback_leibler_divergence: 26.0817
# Epoch 57/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0662 - kullback_leibler_divergence: 26.1804
# Epoch 58/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0653 - kullback_leibler_divergence: 26.1339
# Epoch 59/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0645 - kullback_leibler_divergence: 26.1811
# Epoch 60/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0630 - kullback_leibler_divergence: 26.2028
# Epoch 61/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0619 - kullback_leibler_divergence: 26.2532
# Epoch 62/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0614 - kullback_leibler_divergence: 26.2236
# Epoch 63/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0599 - kullback_leibler_divergence: 26.2019
# Epoch 64/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0593 - kullback_leibler_divergence: 26.2678
# Epoch 65/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0584 - kullback_leibler_divergence: 26.1812
# Epoch 66/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0574 - kullback_leibler_divergence: 26.2081
# Epoch 67/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0568 - kullback_leibler_divergence: 26.2632
# Epoch 68/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0557 - kullback_leibler_divergence: 26.1962
# Epoch 69/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0552 - kullback_leibler_divergence: 26.1440
# Epoch 70/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0542 - kullback_leibler_divergence: 26.2378
# Epoch 71/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0535 - kullback_leibler_divergence: 26.1689
# Epoch 72/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0529 - kullback_leibler_divergence: 26.3030
# Epoch 73/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0521 - kullback_leibler_divergence: 26.1998
# Epoch 74/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0515 - kullback_leibler_divergence: 26.2147
# Epoch 75/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0508 - kullback_leibler_divergence: 26.2109
# Epoch 76/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0502 - kullback_leibler_divergence: 26.2083
# Epoch 77/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0497 - kullback_leibler_divergence: 26.3084
# Epoch 78/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0490 - kullback_leibler_divergence: 26.2104
# Epoch 79/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0487 - kullback_leibler_divergence: 26.2886
# Epoch 80/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0479 - kullback_leibler_divergence: 26.1791
# Epoch 81/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0478 - kullback_leibler_divergence: 26.3254
# Epoch 82/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0475 - kullback_leibler_divergence: 26.1535
# Epoch 83/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0462 - kullback_leibler_divergence: 26.1822
# Epoch 84/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0458 - kullback_leibler_divergence: 26.3000
# Epoch 85/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0455 - kullback_leibler_divergence: 26.0843
# Epoch 86/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0449 - kullback_leibler_divergence: 26.2795
# Epoch 87/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0441 - kullback_leibler_divergence: 26.2379
# Epoch 88/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0437 - kullback_leibler_divergence: 26.2244
# Epoch 89/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0427 - kullback_leibler_divergence: 26.1294
# Epoch 90/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0426 - kullback_leibler_divergence: 26.2223
# Epoch 91/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0420 - kullback_leibler_divergence: 26.2104
# Epoch 92/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0417 - kullback_leibler_divergence: 26.1826
# Epoch 93/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0411 - kullback_leibler_divergence: 26.2643
# Epoch 94/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0414 - kullback_leibler_divergence: 26.2264
# Epoch 95/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0404 - kullback_leibler_divergence: 26.2994
# Epoch 96/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0400 - kullback_leibler_divergence: 26.3230
# Epoch 97/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0396 - kullback_leibler_divergence: 26.2241
# Epoch 98/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0396 - kullback_leibler_divergence: 26.3000
# Epoch 99/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0391 - kullback_leibler_divergence: 26.2744
# Epoch 100/100
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0388 - kullback_leibler_divergence: 26.3271

# %%
X = np.linspace(-2,2,100)
Y = X.copy()
xx,yy = np.meshgrid(X,Y)
labels = student_model.predict(np.c_[xx.ravel(), yy.ravel()])
labels = np.argmax(labels, axis=1)
z = labels.reshape(xx.shape)
 
plt.contour(xx,yy,z, label="Prediction (large)")
plt.scatter(synthetic_inputs[:,0], synthetic_inputs[:,1], c=synthetic_outputs.argmax(axis=1), marker=".", label="original data")
plt.legend()
plt.title("Prediction of large network over original data")
plt.xlabel("Input 0")
plt.ylabel("Input 1")
plt.show()
# Out:
# 313/313 [==============================] - 0s 729us/step
# /var/folders/3g/8436y4yj1r9367dvt15y6jqcdx0hcv/T/ipykernel_63237/1283699916.py:8: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xx,yy,z, label="Prediction (large)")

# %% [markdown]
# # Verify both networks
#
# Assert that the decision is correct inside each quadrant (with some padding)?
#
# Constant Padding
# - Q1: Input 0 > 0.5 and Input 1 > 0.5 => Output 0 == False
# - Q2: Input 0 > 0.5 and Input 1 < -0.5 => Output 0 == True
# - Q3: Input 0 < -0.5 and Input 1 < -0.5 => Output 0 == False
# - Q4: Input 0 > 0.5 and Input 1 < -0.5 => Output 0 == True
#
# Proportional Padding
# - Q1: Input 0 > 1/1000 * Input 1 and Input 1 > 1/1000 * Input 0 => Output 0 == False
# - Q2: Input 0 > 1/1000 * Input 1 and Input 1 < -1/1000 * Input 0 == True
# - Q3: Input 0 < -1/1000 * Input 1 and Input 1 < -1/1000 * Input 0 == False
# - Q4: Input 0 > 1/1000 * Input 1 and Input 1 < -1/1000 * Input 0 == True
#
# ## Data Driven Method
# Ensure that every data point in the dataset satisfying the preconditions evaluate to the correct output.

# %%
padding = 0.5

# This property list is of the format:
# (Name of property, region of input for which it must apply, output value
properties = (
    ("Q1", inputs[:,(inputs[0] > padding) & (inputs[1] > padding)], 0),
    ("Q2", inputs[:,(inputs[0] > padding) & (inputs[1] < -padding)], 1),
    ("Q3", inputs[:,(inputs[0] < -padding) & (inputs[1] < -padding)], 2),
    ("Q4", inputs[:,(inputs[0] < -padding) & (inputs[1] > padding)], 3),
)

for model_name, the_model in [("student", student_model), ("teacher", model)]:
    print(f"Inspecting {model_name}")
    for property_name, property_data, property_output in properties:
        prediction = np.argmax(the_model.predict(property_data.T), axis=1)
        assert (np.abs(prediction - property_output)<0.1).all() , f"{property_name} failed"
        print(f"Model {model_name}, {property_name} property passed!")
# Out:
# Inspecting student
# 3/3 [==============================] - 0s 2ms/step
# Model student, Q1 property passed!
# 2/2 [==============================] - 0s 3ms/step
# Model student, Q2 property passed!
# 3/3 [==============================] - 0s 1ms/step
# Model student, Q3 property passed!
# 2/2 [==============================] - 0s 2ms/step
# Model student, Q4 property passed!
# Inspecting teacher
# 3/3 [==============================] - 0s 2ms/step
# Model teacher, Q1 property passed!
# 2/2 [==============================] - 0s 2ms/step
# Model teacher, Q2 property passed!
# 3/3 [==============================] - 0s 2ms/step
# Model teacher, Q3 property passed!
# 2/2 [==============================] - 0s 2ms/step
# Model teacher, Q4 property passed!

# %% [markdown]
# ## Probabilistic Method
# Ensure that a random samples from within the precondition produce the correct output.

# %%
padding = 0.1
max_distance = 2.0
samples = 4000

# This property list is of the format:
# (Name of property, region of input for which it must apply, output value

probabilistic_inputs = np.random.uniform(padding, max_distance, (2,samples))

for model_name, the_model in [("student", student_model), ("teacher", model)]:
    print(f"Inspecting {model_name}")
    for property_name, property_data, property_output in properties:
        prediction = the_model.predict(property_data.T)
        errors = (np.abs(prediction - property_output) < 0.1)
        if not errors.all():
            print(f"{property_name} failed")
            print(property_data[:,errors.flatten()==False])
            continue
        print(f"Model {model_name}, {property_name} property passed!")
# Out:
# Inspecting student
# 3/3 [==============================] - 0s 1ms/step
# Q1 failed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/jperrsau/cu-src/thesis/src/distill/07_13_2022_distill_data_free.ipynb Cell 21' in <cell line: 10>()
#      <a href='vscode-notebook-cell:/Users/jperrsau/cu-src/thesis/src/distill/07_13_2022_distill_data_free.ipynb#ch0000019?line=14'>15</a> if not errors.all():
#      <a href='vscode-notebook-cell:/Users/jperrsau/cu-src/thesis/src/distill/07_13_2022_distill_data_free.ipynb#ch0000019?line=15'>16</a>     print(f"{property_name} failed")
# ---> <a href='vscode-notebook-cell:/Users/jperrsau/cu-src/thesis/src/distill/07_13_2022_distill_data_free.ipynb#ch0000019?line=16'>17</a>     print(property_data[:,errors.flatten()==False])
#      <a href='vscode-notebook-cell:/Users/jperrsau/cu-src/thesis/src/distill/07_13_2022_distill_data_free.ipynb#ch0000019?line=17'>18</a>     continue
#      <a href='vscode-notebook-cell:/Users/jperrsau/cu-src/thesis/src/distill/07_13_2022_distill_data_free.ipynb#ch0000019?line=18'>19</a> print(f"Model {model_name}, {property_name} property passed!")
#
# IndexError: boolean index did not match indexed array along dimension 1; dimension is 66 but corresponding boolean dimension is 264

# %% [markdown]
# ## Analytic Method
# Ensure that all points within the precondition produce the correct output.
#
# ### Using abstraction
# ### Complete

# %% [markdown]
# ## NNenum

# %%
tf.saved_model.save(student_model, "./distill_test_quadrants_student_model")
tf.saved_model.save(model, "./distill_test_quadrants_model")
# Out:
# INFO:tensorflow:Assets written to: ./distill_test_quadrants_student_model/assets
# INFO:tensorflow:Assets written to: ./distill_test_quadrants_model/assets

# %%
# !python -m tf2onnx.convert --saved-model ./distill_test_quadrants_model/ --output distill_test_model.onnx --opset 11
# !python -m tf2onnx.convert --saved-model ./distill_test_quadrants_student_model/ --output distill_test_student_model.onnx --opset 11
# Out:
# /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2022-07-08 11:36:46,074 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2022-07-08 11:36:46,335 - INFO - Signatures found in model: [serving_default].
# 2022-07-08 11:36:46,335 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2022-07-08 11:36:46,335 - INFO - Output names: ['dense_59']
# WARNING:tensorflow:From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:36:46,387 - WARNING - From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:36:46,401 - INFO - Using tensorflow=2.9.1, onnx=1.12.0, tf2onnx=1.11.1/1915fb
# 2022-07-08 11:36:46,401 - INFO - Using opset <onnx, 11>
# 2022-07-08 11:36:46,411 - INFO - Computed 0 values for constant folding
# 2022-07-08 11:36:46,434 - INFO - Optimizing ONNX model
# 2022-07-08 11:36:46,487 - INFO - After optimization: Identity -5 (5->0)
# 2022-07-08 11:36:46,490 - INFO -
# 2022-07-08 11:36:46,490 - INFO - Successfully converted TensorFlow model ./distill_test_quadrants_model/ to ONNX
# 2022-07-08 11:36:46,491 - INFO - Model inputs: ['dense_56_input']
# 2022-07-08 11:36:46,491 - INFO - Model outputs: ['dense_59']
# 2022-07-08 11:36:46,491 - INFO - ONNX model is saved at distill_test_model.onnx
# /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2022-07-08 11:36:50,891 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2022-07-08 11:36:51,114 - INFO - Signatures found in model: [serving_default].
# 2022-07-08 11:36:51,114 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2022-07-08 11:36:51,114 - INFO - Output names: ['dense_63']
# WARNING:tensorflow:From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:36:51,174 - WARNING - From /Users/jperrsau/opt/anaconda3/envs/distill-env/lib/python3.9/site-packages/tf2onnx/tf_loader.py:711: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-07-08 11:36:51,187 - INFO - Using tensorflow=2.9.1, onnx=1.12.0, tf2onnx=1.11.1/1915fb
# 2022-07-08 11:36:51,187 - INFO - Using opset <onnx, 11>
# 2022-07-08 11:36:51,204 - INFO - Computed 0 values for constant folding
# 2022-07-08 11:36:51,218 - INFO - Optimizing ONNX model
# 2022-07-08 11:36:51,263 - INFO - After optimization: Identity -5 (5->0)
# 2022-07-08 11:36:51,266 - INFO -
# 2022-07-08 11:36:51,266 - INFO - Successfully converted TensorFlow model ./distill_test_quadrants_student_model/ to ONNX
# 2022-07-08 11:36:51,266 - INFO - Model inputs: ['dense_60_input']
# 2022-07-08 11:36:51,266 - INFO - Model outputs: ['dense_63']
# 2022-07-08 11:36:51,266 - INFO - ONNX model is saved at distill_test_student_model.onnx

# %%
property = """
; Quadrant 1 Property

(declare-const X_0 Real)
(declare-const X_1 Real)

(declare-const Y_0 Real)
(declare-const Y_1 Real)
(declare-const Y_2 Real)
(declare-const Y_3 Real)


(assert (>= X_0 0.2))
(assert (<= X_0 1.0))
(assert (>= X_1 0.2))
(assert (<= X_1 1.0))

(assert (<= Y_0 0.0))
"""

with open("distill_quadrant_test.vnnlib", "w") as file:
    file.write(property)

# %%
# !docker run -it -v $(PWD):/my_work nnenum_image python3 -m nnenum.nnenum /my_work/distill_test_model.onnx /my_work/distill_test.vnnlib
